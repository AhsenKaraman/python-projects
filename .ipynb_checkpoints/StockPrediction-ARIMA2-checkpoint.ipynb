# %%
import pandas as pd
import glob

data = 'StockPrediction.csv'
csv_files = glob.glob(data)

frames = []

for csv in csv_files:
    df = pd.read_csv(csv, index_col='date', parse_dates=True)
    frames.append(df)

df = pd.concat(frames)
df.head()
# Out:
#                  price     opening    dailymax    dailymin   volume  \
# date
# 2019-05-08   98.673,28   99.679,44   99.980,56   98.510,21  957,93M
# 2019-02-08   99.679,44  101.508,05  101.706,91   99.629,79  970,54M
# 2019-01-08  101.900,25  101.342,20  102.183,40  101.093,04    1,04B
# 2019-07-31  102.082,48  103.058,70  103.066,33  101.539,66    1,13B
# 2019-07-30  102.686,11  103.519,28  103.552,66  101.969,59    1,15B
#
#            difference\t\t\t\t
# date
# 2019-05-08             -1,01%
# 2019-02-08             -2,18%
# 2019-01-08             -0,18%
# 2019-07-31             -0,59%
# 2019-07-30             -0,66%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3545 entries, 2019-05-08 to 2005-05-07
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           3545 non-null   object
#  1   opening         3545 non-null   object
#  2   dailymax        3545 non-null   object
#  3   dailymin        3545 non-null   object
#  4   volume          3545 non-null   object
#  5   difference				  3545 non-null   object
# dtypes: object(6)
# memory usage: 193.9+ KB

# %%
import pandas as pd
import os
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline

# %%
df['price'] = df['price'].astype(str).str.replace(',','')

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df['opening'] = df['opening'].astype(str).str.replace(',','')

# %%
df['opening'] = pd.to_numeric(df['opening'], errors='coerce')

# %%
df['dailymax'] = df['dailymax'].astype(str).str.replace(',','')

# %%
df['dailymax'] = pd.to_numeric(df['dailymax'], errors='coerce')

# %%
df['dailymin'] = df['dailymin'].astype(str).str.replace(',','')

# %%
df['dailymin'] = pd.to_numeric(df['dailymin'], errors='coerce')

# %%
df['volume'] = df['volume'].astype(str).str.replace('M','')
df['volume'] = df['volume'].astype(str).str.replace('B','')

# %%
df['volume'] = df['volume'].astype(str).str.replace(',','')

# %%
df['volume'] = pd.to_numeric(df['volume'], errors='coerce')

# %%
df['difference\t\t\t\t'] = df['difference\t\t\t\t'].astype(str).str.replace('%','')

# %%
df['difference\t\t\t\t'] = df['difference\t\t\t\t'].astype(str).str.replace(',','.')

# %%
df['difference\t\t\t\t'] = pd.to_numeric(df['difference\t\t\t\t'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3545 entries, 2019-05-08 to 2005-05-07
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           3545 non-null   float64
#  1   opening         3545 non-null   float64
#  2   dailymax        3545 non-null   float64
#  3   dailymin        3545 non-null   float64
#  4   volume          3539 non-null   float64
#  5   difference				  3545 non-null   float64
# dtypes: float64(6)
# memory usage: 193.9 KB

# %%
df.head()
# Out:
#                 price    opening   dailymax   dailymin   volume  \
# date
# 2019-05-08   98.67328   99.67944   99.98056   98.51021  95793.0
# 2019-02-08   99.67944  101.50805  101.70691   99.62979  97054.0
# 2019-01-08  101.90025  101.34220  102.18340  101.09304    104.0
# 2019-07-31  102.08248  103.05870  103.06633  101.53966    113.0
# 2019-07-30  102.68611  103.51928  103.55266  101.96959    115.0
#
#             difference\t\t\t\t
# date
# 2019-05-08               -1.01
# 2019-02-08               -2.18
# 2019-01-08               -0.18
# 2019-07-31               -0.59
# 2019-07-30               -0.66

# %%
df = df.rename(columns={"difference\t\t\t\t":"difference"})

# %%
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
time_series = df['price']

# %%
type(time_series)
# Out:
# pandas.core.series.Series

# %%
time_series.plot(figsize=(20,20))

# %%
time_series.rolling(12).mean().plot(label='12 Month Rolling Mean')
time_series.rolling(12).std().plot(label='12 Month Rolling Std')
time_series.plot()
plt.legend()

# %%
decomp = seasonal_decompose(time_series,period=1)

# %%
fig = decomp.plot()
fig.set_size_inches(16,8)

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(time_series)

# %%
price_diff = time_series.diff(periods=1)

# %%
price_diff.head()
# Out:
# date
# 2019-05-08        NaN
# 2019-02-08    1.00616
# 2019-01-08    2.22081
# 2019-07-31    0.18223
# 2019-07-30    0.60363
# Name: price, dtype: float64

# %%
price_diff = price_diff[1:]
price_diff.head()
# Out:
# date
# 2019-02-08    1.00616
# 2019-01-08    2.22081
# 2019-07-31    0.18223
# 2019-07-30    0.60363
# 2019-07-29    0.68696
# Name: price, dtype: float64

# %%
plot_acf(price_diff)

# %%
price_diff.plot()

# %%
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error

# %%
X = time_series.values

# %%
X.size
# Out:
# 21270

# %%
price_data = df.filter(['price'])

# %%
dataset = price_data.values

# %%
import math

# %%
#Compute the #rows to train the model 
training_data_len = math.ceil( len(dataset) *.8)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Out:
# Using TensorFlow backend.
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
#Scale the all data between 0 and 1 
scaler = MinMaxScaler(feature_range=(0, 1)) 
scaled_data = scaler.fit_transform(dataset)

# %%
#Create scaled training data 
train_data = scaled_data[0:training_data_len  , : ]

# %%
#Spliting data into x_train and y_train
x_train=[]
y_train = []
for i in range(60,len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])

# %%
prediction =[ ]

# %%
#Test data set
test_data = scaled_data[training_data_len - 60: , : ]

# %%
#Create x_test and y_test data
x_test = []
y_test =  dataset[training_data_len : , : ] 
for i in range(60,len(test_data)):
    x_test.append(test_data[i-60:i,0])

# %%
model_ar = AR(train_data)
model_ar_fit = model_ar.fit()

# %%
prediction = model_ar_fit.predict(start=61)

# %%
plt.plot(test_data)
plt.plot(prediction,color='red')

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
#p,d,q  p = periods taken for autoregressive model
#d -> Integrated order, difference
# q periods in moving average model
model_arima = ARIMA(train_data,order=(9, 2, 0))

# %%
model_arima_fit = model_arima.fit()
print(model_arima_fit.aic)
# Out:
# -17494.138117350034

# %%
predictions= model_arima_fit.forecast(steps=10)[0]
predictions
# Out:
# array([0.22557051, 0.22815929, 0.22854785, 0.22946005, 0.23059371,
#        0.2304202 , 0.23253002, 0.23299238, 0.23452673, 0.23558868])

# %%
plt.plot(test_data)
plt.plot(predictions,color='red')

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(time_series)
plt.show()

# %% [markdown]
# Running the example, we can see that there is a positive correlation with the first part

# %%
model = ARIMA(time_series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# /Users/macbook/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
from pandas import DataFrame

# %%
residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                  0
# count  3544.000000
# mean     -0.000012
# std       1.000330
# min      -4.806023
# 25%      -0.582179
# 50%      -0.030199
# 75%       0.526681
# max       8.885859

# %% [markdown]
# First, we get a line plot of the residual errors, suggesting that there may still be some trend information not captured by the model.

# %% [markdown]
# Next, we get a density plot of the residual error values, suggesting the errors are Gaussian, but may not be centered on zero.

# %% [markdown]
# The distribution of the residual errors is displayed. The results show that indeed there is no bias in the prediction. Since mean is 0.

# %%
rmse=np.sqrt(np.mean(((predictions- y_test)**2)))
rmse
# Out:
# 42.449121102627984
